# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv('Salaries.csv')

# %%
# Basic Data Exploration
num_rows, num_cols = df.shape
data_types = df.dtypes
missing_values = df.isnull().sum()

# %%
# Descriptive Statistics
mean_salary = df['TotalPay'].mean()
median_salary = df['TotalPay'].median()
mode_salary = df['TotalPay'].mode().values[0]
min_salary = df['TotalPay'].min()
max_salary = df['TotalPay'].max()
range_salary = max_salary - min_salary
std_salary = df['TotalPay'].std()

# %%
# Data Cleaning
df['TotalPay'].fillna(df['TotalPay'].mean(), inplace=True)

# %%
# Basic Data Visualization
plt.figure(figsize=(10, 6))
sns.histplot(df['TotalPay'], kde=True)
plt.title('Distribution of Salaries')
plt.xlabel('Salary')
plt.ylabel('Count')
plt.show()

# %%
# Grouped Analysis
grouped_data = df.groupby('JobTitle')['TotalPay'].mean()

# %%
# Simple Correlation Analysis
correlation = df['TotalPay'].corr(df['OvertimePay'])
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='TotalPay', y='OvertimePay')
plt.title('Correlation between Salary and Overtime Pay')
plt.xlabel('Salary')
plt.ylabel('Overtime Pay')
plt.show()
